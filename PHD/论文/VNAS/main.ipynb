# %%
import os
import shutil
import tempfile

import matplotlib.pyplot as plt
import numpy as np
from tqdm import tqdm

from monai.losses import DiceCELoss
from monai.inferers import sliding_window_inference
from monai.transforms import (
    AsDiscrete,
    AddChanneld,
    Compose,
    CropForegroundd,
    LoadImaged,
    Orientationd,
    RandFlipd,
    RandCropByPosNegLabeld,
    RandShiftIntensityd,
    ScaleIntensityRanged,
    Spacingd,
    RandRotate90d,
    ToTensord,
)

from monai.config import print_config
from monai.metrics import DiceMetric
from monai.networks.nets import UNETR

from monai.data import (
    DataLoader,
    CacheDataset,
    load_decathlon_datalist,
    decollate_batch,
)


import torch

from V_NAS import Network

# %%
train_transforms = Compose(
    [
        LoadImaged(keys=["image", "label"]),
        AddChanneld(keys=["image", "label"]),
        Orientationd(keys=["image", "label"], axcodes="RAS"),
        Spacingd(
            keys=["image", "label"],
            pixdim=(1.5, 1.5, 2.0),
            mode=("bilinear", "nearest"),
        ),
        ScaleIntensityRanged(
            keys=["image"],
            a_min=-175,
            a_max=250,
            b_min=0.0,
            b_max=1.0,
            clip=True,
        ),
        CropForegroundd(keys=["image", "label"], source_key="image"),
        RandCropByPosNegLabeld(
            keys=["image", "label"],
            label_key="label",
            spatial_size=(96, 96, 96),
            pos=1,
            neg=1,
            num_samples=4,
            image_key="image",
            image_threshold=0,
        ),
        RandFlipd(
            keys=["image", "label"],
            spatial_axis=[0],
            prob=0.10,
        ),
        RandFlipd(
            keys=["image", "label"],
            spatial_axis=[1],
            prob=0.10,
        ),
        RandFlipd(
            keys=["image", "label"],
            spatial_axis=[2],
            prob=0.10,
        ),
        RandRotate90d(
            keys=["image", "label"],
            prob=0.10,
            max_k=3,
        ),
        RandShiftIntensityd(
            keys=["image"],
            offsets=0.10,
            prob=0.50,
        ),
        ToTensord(keys=["image", "label"]),
    ]
)
val_transforms = Compose(
    [
        LoadImaged(keys=["image", "label"]),
        AddChanneld(keys=["image", "label"]),
        Orientationd(keys=["image", "label"], axcodes="RAS"),
        Spacingd(
            keys=["image", "label"],
            pixdim=(1.5, 1.5, 2.0),
            mode=("bilinear", "nearest"),
        ),
        ScaleIntensityRanged(
            keys=["image"], a_min=-175, a_max=250, b_min=0.0, b_max=1.0, clip=True
        ),
        CropForegroundd(keys=["image", "label"], source_key="image"),
        ToTensord(keys=["image", "label"]),
    ]
)

# %%
data_dir = "./data/"
split_JSON = "dataset.json"
datasets = data_dir + split_JSON
# print(datasets)
datalist = load_decathlon_datalist(datasets, True, "training")
# val_files = load_decathlon_datalist(datasets, True, "validation")
train_ds = CacheDataset(
    data=datalist,
    transform=train_transforms,
    cache_num=24,
    cache_rate=1.0,
    
)
train_loader = DataLoader(
    train_ds, batch_size=1, shuffle=True, pin_memory=True
)
# val_ds = CacheDataset(
#     data=val_files, transform=train_transforms, 
#     cache_num=6, 
#     cache_rate=1.0
# )
# val_loader = DataLoader(
#     val_ds, batch_size=1, shuffle=False, pin_memory=True
# )
# Out:
# Loading dataset: 100%|██████████| 24/24 [01:29<00:00,  3.73s/it]

# %%
for i in train_loader:
    print(i, type(i))
    break
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File d:\Software\Anaconda3\envs\dl\lib\site-packages\monai\transforms\transform.py:89, in apply_transform(transform, data, map_items, unpack_items, log_stats)
#      <a href='file:///d%3A/Software/Anaconda3/envs/dl/lib/site-packages/monai/transforms/transform.py?line=87'>88</a>         return [_apply_transform(transform, item, unpack_items) for item in data]
# ---> <a href='file:///d%3A/Software/Anaconda3/envs/dl/lib/site-packages/monai/transforms/transform.py?line=88'>89</a>     return _apply_transform(transform, data, unpack_items)
#      <a href='file:///d%3A/Software/Anaconda3/envs/dl/lib/site-packages/monai/transforms/transform.py?line=89'>90</a> except Exception as e:
#
# File d:\Software\Anaconda3\envs\dl\lib\site-packages\monai\transforms\transform.py:53, in _apply_transform(transform, parameters, unpack_parameters)
#      <a href='file:///d%3A/Software/Anaconda3/envs/dl/lib/site-packages/monai/transforms/transform.py?line=50'>51</a>     return transform(*parameters)
# ---> <a href='file:///d%3A/Software/Anaconda3/envs/dl/lib/site-packages/monai/transforms/transform.py?line=52'>53</a> return transform(parameters)
#
# File d:\Software\Anaconda3\envs\dl\lib\site-packages\monai\transforms\croppad\dictionary.py:1171, in RandCropByPosNegLabeld.__call__(self, data)
#    <a href='file:///d%3A/Software/Anaconda3/envs/dl/lib/site-packages/monai/transforms/croppad/dictionary.py?line=1168'>1169</a> bg_indices = d.pop(self.bg_indices_key, None) if self.bg_indices_key is not None else None
# -> <a href='file:///d%3A/Software/Anaconda3/envs/dl/lib/site-packages/monai/transforms/croppad/dictionary.py?line=1170'>1171</a> self.randomize(label, fg_indices, bg_indices, image)
#    <a href='file:///d%3A/Software/Anaconda3/envs/dl/lib/site-packages/monai/transforms/croppad/dictionary.py?line=1171'>1172</a> if not isinstance(self.spatial_size, tuple):
#
# File d:\Software\Anaconda3\envs\dl\lib\site-packages\monai\transforms\croppad\dictionary.py:1153, in RandCropByPosNegLabeld.randomize(self, label, fg_indices, bg_indices, image)
#    <a href='file:///d%3A/Software/Anaconda3/envs/dl/lib/site-packages/monai/transforms/croppad/dictionary.py?line=1151'>1152</a>     bg_indices_ = bg_indices
# -> <a href='file:///d%3A/Software/Anaconda3/envs/dl/lib/site-packages/monai/transforms/croppad/dictionary.py?line=1152'>1153</a> self.centers = generate_pos_neg_label_crop_centers(
#    <a href='file:///d%3A/Software/Anaconda3/envs/dl/lib/site-packages/monai/transforms/croppad/dictionary.py?line=1153'>1154</a>     self.spatial_size,
#    <a href='file:///d%3A/Software/Anaconda3/envs/dl/lib/site-packages/monai/transforms/croppad/dictionary.py?line=1154'>1155</a>     self.num_samples,
#    <a href='file:///d%3A/Software/Anaconda3/envs/dl/lib/site-packages/monai/transforms/croppad/dictionary.py?line=1155'>1156</a>     self.pos_ratio,
#    <a href='file:///d%3A/Software/Anaconda3/envs/dl/lib/site-packages/monai/transforms/croppad/dictionary.py?line=1156'>1157</a>     label.shape[1:],
#    <a href='file:///d%3A/Software/Anaconda3/envs/dl/lib/site-packages/monai/transforms/croppad/dictionary.py?line=1157'>1158</a>     fg_indices_,
#    <a href='file:///d%3A/Software/Anaconda3/envs/dl/lib/site-packages/monai/transforms/croppad/dictionary.py?line=1158'>1159</a>     bg_indices_,
#    <a href='file:///d%3A/Software/Anaconda3/envs/dl/lib/site-packages/monai/transforms/croppad/dictionary.py?line=1159'>1160</a>     self.R,
#    <a href='file:///d%3A/Software/Anaconda3/envs/dl/lib/site-packages/monai/transforms/croppad/dictionary.py?line=1160'>1161</a>     self.allow_smaller,
#    <a href='file:///d%3A/Software/Anaconda3/envs/dl/lib/site-packages/monai/transforms/croppad/dictionary.py?line=1161'>1162</a> )
#
# File d:\Software\Anaconda3\envs\dl\lib\site-packages\monai\transforms\utils.py:512, in generate_pos_neg_label_crop_centers(spatial_size, num_samples, pos_ratio, label_spatial_shape, fg_indices, bg_indices, rand_state, allow_smaller)
#     <a href='file:///d%3A/Software/Anaconda3/envs/dl/lib/site-packages/monai/transforms/utils.py?line=510'>511</a>     # shift center to range of valid centers
# --> <a href='file:///d%3A/Software/Anaconda3/envs/dl/lib/site-packages/monai/transforms/utils.py?line=511'>512</a>     centers.append(correct_crop_centers(center, spatial_size, label_spatial_shape, allow_smaller))
#     <a href='file:///d%3A/Software/Anaconda3/envs/dl/lib/site-packages/monai/transforms/utils.py?line=513'>514</a> return centers
#
# File d:\Software\Anaconda3\envs\dl\lib\site-packages\monai\transforms\utils.py:439, in correct_crop_centers(centers, spatial_size, label_spatial_shape, allow_smaller)
#     <a href='file:///d%3A/Software/Anaconda3/envs/dl/lib/site-packages/monai/transforms/utils.py?line=437'>438</a> if not allow_smaller:
# --> <a href='file:///d%3A/Software/Anaconda3/envs/dl/lib/site-packages/monai/transforms/utils.py?line=438'>439</a>     raise ValueError("The size of the proposed random crop ROI is larger than the image size.")
#     <a href='file:///d%3A/Software/Anaconda3/envs/dl/lib/site-packages/monai/transforms/utils.py?line=439'>440</a> spatial_size = tuple(min(l, s) for l, s in zip(label_spatial_shape, spatial_size))
#
# ValueError: The size of the proposed random crop ROI is larger than the image size.
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# File d:\Software\Anaconda3\envs\dl\lib\site-packages\monai\transforms\transform.py:89, in apply_transform(transform, data, map_items, unpack_items, log_stats)
#      <a href='file:///d%3A/Software/Anaconda3/envs/dl/lib/site-packages/monai/transforms/transform.py?line=87'>88</a>         return [_apply_transform(transform, item, unpack_items) for item in data]
# ---> <a href='file:///d%3A/Software/Anaconda3/envs/dl/lib/site-packages/monai/transforms/transform.py?line=88'>89</a>     return _apply_transform(transform, data, unpack_items)
#      <a href='file:///d%3A/Software/Anaconda3/envs/dl/lib/site-packages/monai/transforms/transform.py?line=89'>90</a> except Exception as e:
#
# File d:\Software\Anaconda3\envs\dl\lib\site-packages\monai\transforms\transform.py:53, in _apply_transform(transform, parameters, unpack_parameters)
#      <a href='file:///d%3A/Software/Anaconda3/envs/dl/lib/site-packages/monai/transforms/transform.py?line=50'>51</a>     return transform(*parameters)
# ---> <a href='file:///d%3A/Software/Anaconda3/envs/dl/lib/site-packages/monai/transforms/transform.py?line=52'>53</a> return transform(parameters)
#
# File d:\Software\Anaconda3\envs\dl\lib\site-packages\monai\transforms\compose.py:173, in Compose.__call__(self, input_)
#     <a href='file:///d%3A/Software/Anaconda3/envs/dl/lib/site-packages/monai/transforms/compose.py?line=171'>172</a> for _transform in self.transforms:
# --> <a href='file:///d%3A/Software/Anaconda3/envs/dl/lib/site-packages/monai/transforms/compose.py?line=172'>173</a>     input_ = apply_transform(_transform, input_, self.map_items, self.unpack_items, self.log_stats)
#     <a href='file:///d%3A/Software/Anaconda3/envs/dl/lib/site-packages/monai/transforms/compose.py?line=173'>174</a> return input_
#
# File d:\Software\Anaconda3\envs\dl\lib\site-packages\monai\transforms\transform.py:113, in apply_transform(transform, data, map_items, unpack_items, log_stats)
#     <a href='file:///d%3A/Software/Anaconda3/envs/dl/lib/site-packages/monai/transforms/transform.py?line=111'>112</a>         _log_stats(data=data)
# --> <a href='file:///d%3A/Software/Anaconda3/envs/dl/lib/site-packages/monai/transforms/transform.py?line=112'>113</a> raise RuntimeError(f"applying transform {transform}") from e
#
# RuntimeError: applying transform <monai.transforms.croppad.dictionary.RandCropByPosNegLabeld object at 0x0000023F47BB8CD0>
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# d:\Projects\my_phd\PHD\论文\VNAS\main.ipynb Cell 4' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/d%3A/Projects/my_phd/PHD/%E8%AE%BA%E6%96%87/VNAS/main.ipynb#ch0000004?line=0'>1</a> for i in train_loader:
#       <a href='vscode-notebook-cell:/d%3A/Projects/my_phd/PHD/%E8%AE%BA%E6%96%87/VNAS/main.ipynb#ch0000004?line=1'>2</a>     print(i, type(i))
#       <a href='vscode-notebook-cell:/d%3A/Projects/my_phd/PHD/%E8%AE%BA%E6%96%87/VNAS/main.ipynb#ch0000004?line=2'>3</a>     break
#
# File d:\Software\Anaconda3\envs\dl\lib\site-packages\torch\utils\data\dataloader.py:530, in _BaseDataLoaderIter.__next__(self)
#     <a href='file:///d%3A/Software/Anaconda3/envs/dl/lib/site-packages/torch/utils/data/dataloader.py?line=527'>528</a> if self._sampler_iter is None:
#     <a href='file:///d%3A/Software/Anaconda3/envs/dl/lib/site-packages/torch/utils/data/dataloader.py?line=528'>529</a>     self._reset()
# --> <a href='file:///d%3A/Software/Anaconda3/envs/dl/lib/site-packages/torch/utils/data/dataloader.py?line=529'>530</a> data = self._next_data()
#     <a href='file:///d%3A/Software/Anaconda3/envs/dl/lib/site-packages/torch/utils/data/dataloader.py?line=530'>531</a> self._num_yielded += 1
#     <a href='file:///d%3A/Software/Anaconda3/envs/dl/lib/site-packages/torch/utils/data/dataloader.py?line=531'>532</a> if self._dataset_kind == _DatasetKind.Iterable and \
#     <a href='file:///d%3A/Software/Anaconda3/envs/dl/lib/site-packages/torch/utils/data/dataloader.py?line=532'>533</a>         self._IterableDataset_len_called is not None and \
#     <a href='file:///d%3A/Software/Anaconda3/envs/dl/lib/site-packages/torch/utils/data/dataloader.py?line=533'>534</a>         self._num_yielded > self._IterableDataset_len_called:
#
# File d:\Software\Anaconda3\envs\dl\lib\site-packages\torch\utils\data\dataloader.py:570, in _SingleProcessDataLoaderIter._next_data(self)
#     <a href='file:///d%3A/Software/Anaconda3/envs/dl/lib/site-packages/torch/utils/data/dataloader.py?line=567'>568</a> def _next_data(self):
#     <a href='file:///d%3A/Software/Anaconda3/envs/dl/lib/site-packages/torch/utils/data/dataloader.py?line=568'>569</a>     index = self._next_index()  # may raise StopIteration
# --> <a href='file:///d%3A/Software/Anaconda3/envs/dl/lib/site-packages/torch/utils/data/dataloader.py?line=569'>570</a>     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     <a href='file:///d%3A/Software/Anaconda3/envs/dl/lib/site-packages/torch/utils/data/dataloader.py?line=570'>571</a>     if self._pin_memory:
#     <a href='file:///d%3A/Software/Anaconda3/envs/dl/lib/site-packages/torch/utils/data/dataloader.py?line=571'>572</a>         data = _utils.pin_memory.pin_memory(data)
#
# File d:\Software\Anaconda3\envs\dl\lib\site-packages\torch\utils\data\_utils\fetch.py:49, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      <a href='file:///d%3A/Software/Anaconda3/envs/dl/lib/site-packages/torch/utils/data/_utils/fetch.py?line=46'>47</a> def fetch(self, possibly_batched_index):
#      <a href='file:///d%3A/Software/Anaconda3/envs/dl/lib/site-packages/torch/utils/data/_utils/fetch.py?line=47'>48</a>     if self.auto_collation:
# ---> <a href='file:///d%3A/Software/Anaconda3/envs/dl/lib/site-packages/torch/utils/data/_utils/fetch.py?line=48'>49</a>         data = [self.dataset[idx] for idx in possibly_batched_index]
#      <a href='file:///d%3A/Software/Anaconda3/envs/dl/lib/site-packages/torch/utils/data/_utils/fetch.py?line=49'>50</a>     else:
#      <a href='file:///d%3A/Software/Anaconda3/envs/dl/lib/site-packages/torch/utils/data/_utils/fetch.py?line=50'>51</a>         data = self.dataset[possibly_batched_index]
#
# File d:\Software\Anaconda3\envs\dl\lib\site-packages\torch\utils\data\_utils\fetch.py:49, in <listcomp>(.0)
#      <a href='file:///d%3A/Software/Anaconda3/envs/dl/lib/site-packages/torch/utils/data/_utils/fetch.py?line=46'>47</a> def fetch(self, possibly_batched_index):
#      <a href='file:///d%3A/Software/Anaconda3/envs/dl/lib/site-packages/torch/utils/data/_utils/fetch.py?line=47'>48</a>     if self.auto_collation:
# ---> <a href='file:///d%3A/Software/Anaconda3/envs/dl/lib/site-packages/torch/utils/data/_utils/fetch.py?line=48'>49</a>         data = [self.dataset[idx] for idx in possibly_batched_index]
#      <a href='file:///d%3A/Software/Anaconda3/envs/dl/lib/site-packages/torch/utils/data/_utils/fetch.py?line=49'>50</a>     else:
#      <a href='file:///d%3A/Software/Anaconda3/envs/dl/lib/site-packages/torch/utils/data/_utils/fetch.py?line=50'>51</a>         data = self.dataset[possibly_batched_index]
#
# File d:\Software\Anaconda3\envs\dl\lib\site-packages\monai\data\dataset.py:97, in Dataset.__getitem__(self, index)
#      <a href='file:///d%3A/Software/Anaconda3/envs/dl/lib/site-packages/monai/data/dataset.py?line=93'>94</a> if isinstance(index, collections.abc.Sequence):
#      <a href='file:///d%3A/Software/Anaconda3/envs/dl/lib/site-packages/monai/data/dataset.py?line=94'>95</a>     # dataset[[1, 3, 4]]
#      <a href='file:///d%3A/Software/Anaconda3/envs/dl/lib/site-packages/monai/data/dataset.py?line=95'>96</a>     return Subset(dataset=self, indices=index)
# ---> <a href='file:///d%3A/Software/Anaconda3/envs/dl/lib/site-packages/monai/data/dataset.py?line=96'>97</a> return self._transform(index)
#
# File d:\Software\Anaconda3\envs\dl\lib\site-packages\monai\data\dataset.py:792, in CacheDataset._transform(self, index)
#     <a href='file:///d%3A/Software/Anaconda3/envs/dl/lib/site-packages/monai/data/dataset.py?line=787'>788</a>         index_ = key  # if using hash as cache keys, set the key
#     <a href='file:///d%3A/Software/Anaconda3/envs/dl/lib/site-packages/monai/data/dataset.py?line=789'>790</a> if isinstance(index_, int) and index_ % len(self) >= self.cache_num:  # support negative index
#     <a href='file:///d%3A/Software/Anaconda3/envs/dl/lib/site-packages/monai/data/dataset.py?line=790'>791</a>     # no cache for this index, execute all the transforms directly
# --> <a href='file:///d%3A/Software/Anaconda3/envs/dl/lib/site-packages/monai/data/dataset.py?line=791'>792</a>     return super()._transform(index_)
#     <a href='file:///d%3A/Software/Anaconda3/envs/dl/lib/site-packages/monai/data/dataset.py?line=792'>793</a> # load data from cache and execute from the first random transform
#     <a href='file:///d%3A/Software/Anaconda3/envs/dl/lib/site-packages/monai/data/dataset.py?line=793'>794</a> start_run = False
#
# File d:\Software\Anaconda3\envs\dl\lib\site-packages\monai\data\dataset.py:83, in Dataset._transform(self, index)
#      <a href='file:///d%3A/Software/Anaconda3/envs/dl/lib/site-packages/monai/data/dataset.py?line=78'>79</a> """
#      <a href='file:///d%3A/Software/Anaconda3/envs/dl/lib/site-packages/monai/data/dataset.py?line=79'>80</a> Fetch single data item from `self.data`.
#      <a href='file:///d%3A/Software/Anaconda3/envs/dl/lib/site-packages/monai/data/dataset.py?line=80'>81</a> """
#      <a href='file:///d%3A/Software/Anaconda3/envs/dl/lib/site-packages/monai/data/dataset.py?line=81'>82</a> data_i = self.data[index]
# ---> <a href='file:///d%3A/Software/Anaconda3/envs/dl/lib/site-packages/monai/data/dataset.py?line=82'>83</a> return apply_transform(self.transform, data_i) if self.transform is not None else data_i
#
# File d:\Software\Anaconda3\envs\dl\lib\site-packages\monai\transforms\transform.py:113, in apply_transform(transform, data, map_items, unpack_items, log_stats)
#     <a href='file:///d%3A/Software/Anaconda3/envs/dl/lib/site-packages/monai/transforms/transform.py?line=110'>111</a>     else:
#     <a href='file:///d%3A/Software/Anaconda3/envs/dl/lib/site-packages/monai/transforms/transform.py?line=111'>112</a>         _log_stats(data=data)
# --> <a href='file:///d%3A/Software/Anaconda3/envs/dl/lib/site-packages/monai/transforms/transform.py?line=112'>113</a> raise RuntimeError(f"applying transform {transform}") from e
#
# RuntimeError: applying transform <monai.transforms.compose.Compose object at 0x0000023F47BF0B80>
