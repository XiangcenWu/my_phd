# %%
# import torch
from livelossplot import PlotLosses
import time
import numpy as np

# %%
plot = PlotLosses()

for i in range(10):
    plot.update({
        'acc': i,
        'val_acc': i,
        'loss': i,
        'val_loss': i
    })
    plot.send()
    time.sleep(0.6)
# Out:
# Accuracy
# 	training         	 (min:    0.000, max:    9.000, cur:    9.000)
# 	validation       	 (min:    0.000, max:    9.000, cur:    9.000)
# Loss
# 	training         	 (min:    0.000, max:    9.000, cur:    9.000)
# 	validation       	 (min:    0.000, max:    9.000, cur:    9.000)
